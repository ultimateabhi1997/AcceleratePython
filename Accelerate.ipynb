# %%
import pandas as pd
df=pd.read_excel(r'C:\Users\Abhishek\Desktop\2 JMPSheetCreation\Input\FG_Worker_list.xls')
print(df)
# Out:
#       Security ID  Buyer Reference                           SOW Worker Name  \
# 0               -              NaN                   Acharya, Radhika Suresh
# 1               -              NaN                   Acharya, Radhika Suresh
# 2               -              NaN                           Adhwaryu, Nitij
# 3               -              NaN                           Adhwaryu, Nitij
# 4               -              NaN                            Agarwal, Pooja
# 5               -              NaN                            Agarwal, Pooja
# 6               -              NaN                            Agarwal, Pooja
# 7               -              NaN                            Agarwal, Pooja
# 8               -              NaN                            Agarwal, Pooja
# 9               -              NaN                            Agarwal, Pooja
# 10              -              NaN                            Agrawal, Vivek
# ...

# %%
df.drop_duplicates(subset="Worker ID",keep=False,inplace=True)

# %%
print(df)
# Out:
#       Security ID  Buyer Reference              SOW Worker Name  \
# 8               -              NaN               Agarwal, Pooja
# 9               -              NaN               Agarwal, Pooja
# 18              -              NaN                Ahmad, Tausif
# 27              -              NaN        Alwala, Srikanth Goud
# 28              -              NaN                  Amol, Borse
# 37              -              NaN        Awati, Pravin Sukumar
# 40              -              NaN      Bansode, Aniket Mahadeo
# 47              -              NaN              Behera, Bhabani
# 48              -              NaN              Behera, Bhabani
# 49              -              NaN           Behera, Satyabrata
# 50              -              NaN                Bhad, Mangesh
# 51              -              NaN               Bhagat, Ashwin
# 56              -              NaN             Bhamare, Pradeep
# 57              -              NaN             Bhamare, Pradeep
# ...

# %%
print(df.shape)
# Out:
# (842, 26)

# %%
df_filtered=df[df['Worker Start Date']<=df['Worker End Date']]

# %%
print(df_filtered)
# Out:
#       Security ID  Buyer Reference              SOW Worker Name  \
# 8               -              NaN               Agarwal, Pooja
# 9               -              NaN               Agarwal, Pooja
# 18              -              NaN                Ahmad, Tausif
# 27              -              NaN        Alwala, Srikanth Goud
# 28              -              NaN                  Amol, Borse
# 37              -              NaN        Awati, Pravin Sukumar
# 40              -              NaN      Bansode, Aniket Mahadeo
# 47              -              NaN              Behera, Bhabani
# 48              -              NaN              Behera, Bhabani
# 49              -              NaN           Behera, Satyabrata
# 50              -              NaN                Bhad, Mangesh
# 51              -              NaN               Bhagat, Ashwin
# 56              -              NaN             Bhamare, Pradeep
# 57              -              NaN             Bhamare, Pradeep
# ...
